# %% [markdown]
# Exp8 AI API

# %%
from google import genai

client = genai.Client(api_key="AIzaSyCCl5oWA7z_bIK-wB-d2NKWnS1Vtf9PnO4")

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-3-41553ff07890> in <cell line: 0>()
#       3 client = genai.Client(api_key="AIzaSyCCl5oWA7z_bIK-wB-d2NKWnS1Vtf9PnO4")
#       4
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-2.0-flash",
#       7     contents="Explain how AI works in a few words",
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5017     while remaining_remote_calls_afc > 0:
#    5018       i += 1
# -> 5019       response = self._generate_content(
#    5020           model=model, contents=contents, config=config
#    5021       )
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    3993     request_dict = _common.encode_unserializable_types(request_dict)
#    3994
# ...
